# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("RCBdata.csv")

# %%
print(data.head())
# Out:
#        id  inning  over  ball     batsman      bowler  batsman_runs  \
# 0  335982       2     6     2    CL White  AB Agarkar             0
# 1  335982       2     6     3    CL White  AB Agarkar             1
# 2  335982       2     6     4  MV Boucher  AB Agarkar             0
# 3  335982       2     6     5  MV Boucher  AB Agarkar             0
# 4  335982       2     6     6  MV Boucher  AB Agarkar             0
#
#    total_runs  is_wicket dismissal_kind player_dismissed  \
# 0           0          0            NaN              NaN
# 1           1          0            NaN              NaN
# 2           1          0            NaN              NaN
# 3           1          0            NaN              NaN
# 4           0          0            NaN              NaN
#
#                   batting_team           bowling_team
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  Royal Challengers Bangalore  Kolkata Knight Riders
# ...

# %%
print(data.tail())
# Out:
#             id  inning  over  ball         batsman          bowler  \
# 22701  1237178       1    19     3        NA Saini     T Natarajan
# 22702  1237178       1    19     4  Mohammed Siraj     T Natarajan
# 22703  1237178       1    19     5  Mohammed Siraj     T Natarajan
# 22704  1237178       1    19     6  Mohammed Siraj     T Natarajan
# 22705  1237178       1     0     4         V Kohli  Sandeep Sharma
#
#        batsman_runs  total_runs  is_wicket dismissal_kind player_dismissed  \
# 22701             1           1          0            NaN              NaN
# 22702             2           2          0            NaN              NaN
# 22703             4           4          0            NaN              NaN
# 22704             2           2          0            NaN              NaN
# 22705             2           2          0            NaN              NaN
#
#                       batting_team         bowling_team
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22706 entries, 0 to 22705
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                22706 non-null  int64
#  1   inning            22706 non-null  int64
#  2   over              22706 non-null  int64
#  3   ball              22706 non-null  int64
#  4   batsman           22706 non-null  object
#  5   bowler            22706 non-null  object
#  6   batsman_runs      22706 non-null  int64
#  7   total_runs        22706 non-null  int64
#  8   is_wicket         22706 non-null  int64
#  9   dismissal_kind    1116 non-null   object
#  10  player_dismissed  1116 non-null   object
#  11  batting_team      22706 non-null  object
#  12  bowling_team      22578 non-null  object
# dtypes: int64(7), object(6)
# memory usage: 2.3+ MB
# None

# %%
print(data.batsman.unique())
# Out:
# ['CL White' 'MV Boucher' 'B Akhil' 'AA Noffke' 'P Kumar' 'Z Khan'
#  'SB Joshi' 'W Jaffer' 'JH Kallis' 'R Dravid' 'V Kohli' 'S Chanderpaul'
#  'LRPL Taylor' 'R Vinay Kumar' 'B Chipli' 'DW Steyn' 'Misbah-ul-Haq'
#  'DT Patil' 'A Kumble' 'J Arunkumar' 'SP Goswami' 'Abdur Razzak'
#  'KP Pietersen' 'JD Ryder' 'RV Uthappa' 'R Bishnoi' 'KV Sharma'
#  'Pankaj Singh' 'RE van der Merwe' 'MK Pandey' 'KP Appanna' 'D du Preez'
#  'EJG Morgan' 'A Mithun' 'S Sriram' 'MA Agarwal' 'AB de Villiers'
#  'SS Tiwary' 'TM Dilshan' 'AUK Pathan' 'CA Pujara' 'JJ van der Wath'
#  'R Ninan' 'DL Vettori' 'S Aravind' 'CH Gayle' 'J Syed Mohammad' 'M Kaif'
#  'KB Arun Karthik' 'LA Pomersbach' 'CK Langeveldt' 'AB McDonald'
#  'HV Patel' 'RR Bhatkal' 'M Muralitharan' 'P Parameswaran' 'DT Christian'
#  'KK Nair' 'MC Henriques' 'M Kartik' 'JD Unadkat' 'R Rampaul' 'KL Rahul'
#  'A Mukund' 'PA Patel' 'NJ Maddinson' 'Yuvraj Singh' 'YV Takawale'
#  'JA Morkel' 'S Rana' 'AB Dinda' 'MA Starc' 'VR Aaron' 'RR Rossouw'
# ...

# %%
print(data.bowler.nunique())
# Out:
# 277

# %%
print(data.columns)
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'bowler', 'batsman_runs',
#        'total_runs', 'is_wicket', 'dismissal_kind', 'player_dismissed',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
print(data[
    ["batting_team", "batsman", "bowling_team", "player_dismissed"]
].head())
# Out:
#                   batting_team     batsman           bowling_team  \
# 0  Royal Challengers Bangalore    CL White  Kolkata Knight Riders
# 1  Royal Challengers Bangalore    CL White  Kolkata Knight Riders
# 2  Royal Challengers Bangalore  MV Boucher  Kolkata Knight Riders
# 3  Royal Challengers Bangalore  MV Boucher  Kolkata Knight Riders
# 4  Royal Challengers Bangalore  MV Boucher  Kolkata Knight Riders
#
#   player_dismissed
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
data.describe()
# Out:
#                  id        inning          over          ball  batsman_runs  \
# count  2.270600e+04  22706.000000  22706.000000  22706.000000  22706.000000
# mean   7.550214e+05      1.491852      9.114287      3.615080      1.265789
# std    3.097264e+05      0.499945      5.675441      1.807369      1.652009
# min    3.359820e+05      1.000000      0.000000      1.000000      0.000000
# 25%    5.012080e+05      1.000000      4.000000      2.000000      0.000000
# 50%    7.293050e+05      1.000000      9.000000      4.000000      1.000000
# 75%    1.082621e+06      2.000000     14.000000      5.000000      1.000000
# max    1.237178e+06      2.000000     19.000000      9.000000      6.000000
#
#          total_runs     is_wicket
# count  22706.000000  22706.000000
# mean       1.330661      0.049150
# std        1.639839      0.216186
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      0.000000
# ...

# %%
# Creating a mock dataset with the given schema for visualization
data = {
    'id': range(22706),
    'inning': [1, 2] * 11353,
    'over': [i % 20 + 1 for i in range(22706)],
    'ball': [i % 6 + 1 for i in range(22706)],
    'batsman': [f'Batsman_{i % 50}' for i in range(22706)],
    'bowler': [f'Bowler_{i % 30}' for i in range(22706)],
    'batsman_runs': [i % 7 for i in range(22706)],
    'total_runs': [i % 8 for i in range(22706)],
    'is_wicket': [0 if i % 21 else 1 for i in range(22706)],
    'dismissal_kind': [None if i % 21 else 'Caught' for i in range(22706)],
    'player_dismissed': [None if i % 21 else f'Batsman_{i % 50}' for i in range(22706)],
    'batting_team': [f'Team_{i % 10}' for i in range(22706)],
    'bowling_team': [f'Team_{(i+1) % 10}' for i in range(22578)] + [None] * 128,
}
df = pd.DataFrame(data)

# 1. Top 10 Batsmen by Total Runs Scored
top_batsmen = df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_batsmen.values, y=top_batsmen.index, palette="viridis")
plt.title("Top 10 Batsmen by Total Runs")
plt.xlabel("Total Runs")
plt.ylabel("Batsman")
plt.show()

# %%
# 4. Total Runs by Batting Teams
runs_by_teams = df.groupby('batting_team')['total_runs'].sum().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x=runs_by_teams.values, y=runs_by_teams.index, palette="mako")
plt.title("Total Runs by Batting Teams")
plt.xlabel("Total Runs")
plt.ylabel("Batting Team")
plt.show()

# %%
wicket_data = df['is_wicket'].value_counts()
labels = ['No Wicket', 'Wicket']
colors = ['skyblue', 'salmon']
plt.figure(figsize=(8, 8))
plt.pie(wicket_data, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, explode=[0, 0.1])
plt.title("Proportion of Balls Resulting in Wickets")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=runs_by_teams.index, y=runs_by_teams.values, palette="viridis")
plt.title("Total Runs by Batting Teams", fontsize=14)
plt.xlabel("Batting Team", fontsize=12)
plt.ylabel("Total Runs", fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='over', y='total_runs', hue='inning', palette="cool", alpha=0.7)
plt.title("Scatter Plot of Runs Scored per Over", fontsize=14)
plt.xlabel("Over", fontsize=12)
plt.ylabel("Total Runs", fontsize=12)
plt.legend(title="Inning", loc="upper right")
plt.grid(alpha=0.3)
plt.show()

# %%
wickets_per_over = df.groupby('over')['is_wicket'].sum()

# Plotting the line graph
plt.figure(figsize=(10, 6))
sns.lineplot(x=wickets_per_over.index, y=wickets_per_over.values, marker='o', color='r', linewidth=2)
plt.title("Wickets Taken per Over", fontsize=14)
plt.xlabel("Over", fontsize=12)
plt.ylabel("Wickets", fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['total_runs'], bins=8, color='green', edgecolor='black', alpha=0.8)
plt.title("Distribution of Total Runs per Over", fontsize=14)
plt.xlabel("Runs per Over", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#    over  total_runs
# 0     1           0
# 1     2           1
# 2     3           2
# 3     4           3
# 4     5           4
